# %%
import h5py
import numpy as np

# Open the HDF5 file in read/write mode
with h5py.File('./dumps/prim.h5', 'r+') as file:
    # Read the dataset containing the quantity (assuming it's named 'data')
    for key in file.keys():
        # Check if the key corresponds to a dataset
        if isinstance(file[key], h5py.Dataset):
            print(f"Dataset: {key}")
        elif isinstance(file[key], h5py.Group):
            print(f"Group: {key}")
            # Access the datasets or groups within the file 
    rho = file['rho'][:]
    print(rho.shape)
# Out:
# Dataset: b1
# Dataset: b2
# Dataset: b3
# Dataset: rho
# Dataset: u1
# Dataset: u2
# Dataset: u3
# Dataset: uu
# Dataset: ye
# (32, 32, 32)

# %%
print(rho[:,0,0])
# Out:
# [3.19226689e-04 3.21252784e-04 3.27733855e-04 3.43549253e-04
#  3.70532569e-04 4.25578423e-04 4.93655709e-04 5.77722372e-04
#  6.07000975e-04 6.36786063e-04 6.80809649e-04 7.14482520e-04
#  7.06871665e-04 6.11784353e-04 5.09866918e-04 4.19157365e-04
#  3.65283253e-04 3.20604576e-04 2.79830052e-04 2.41406800e-04
#  2.09353529e-04 1.83687353e-04 1.75679114e-04 1.78306380e-04
#  1.84251283e-04 1.71022955e-04 1.50859871e-04 1.26201860e-04
#  1.04413043e-04 8.67992431e-05 7.29356299e-05 7.14236720e-05]

# %%
# Open the HDF5 file in read/write mode
with h5py.File('./dumps/grid.h5', 'r+') as file:
    # Read the dataset containing the quantity (assuming it's named 'data')
    for key in file.keys():
        # Check if the key corresponds to a dataset
        if isinstance(file[key], h5py.Dataset):
            print(f"Dataset: {key}")
        elif isinstance(file[key], h5py.Group):
            print(f"Group: {key}")
            # Access the datasets or groups within the file 
    Xcart = file['Xcart'][:]
    print(Xcart.shape)
# Out:
# Dataset: Gamma
# Dataset: Lambda_h2cart_con
# Dataset: Lambda_h2cart_cov
# Dataset: XFcart
# Dataset: XFharm
# Dataset: Xcart
# Dataset: Xharm
# Dataset: alpha
# Dataset: gcon
# Dataset: gcov
# Dataset: gdet
# (32, 32, 32, 4)

# %%
print(Xcart[:,0,0,1])
# Out:
# [ 35.5  42.5  49.5  56.5  63.5  70.5  77.5  84.5  91.5  98.5 105.5 112.5
#  119.5 126.5 133.5 140.5 147.5 154.5 161.5 168.5 175.5 182.5 189.5 196.5
#  203.5 210.5 217.5 224.5 231.5 238.5 245.5 252.5]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Xcart[:,0,0,1], rho[:,0,0])
